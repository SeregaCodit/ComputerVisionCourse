# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from core.constants import Paths as p

# %%
img_path = p.IMAGE_ASSETS / "cat1.png"

# %%
img = cv2.imread(img_path)
plt.figure()
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
eye_pixel = img_rgb[468, 252]
eye_pixel
# Out:
# array([73, 72, 78], dtype=uint8)

# %%
img_rgb[240, 556] = (255, 0, 0)
plt.imshow(img_rgb)

# %% [markdown]
# # Pixel REGION

# %%
eye_region = img_rgb[222:253, 535: 580]
plt.imshow(eye_region)

# %%
dx = 580 - 535
dy = 253 - 222
cx = 489
cy = 188

strat_x = cx - (dx // 2)
strat_y = cy - (dy // 2)

# %%
img_rgb[strat_y: strat_y + dy, strat_x: strat_x + dx] = eye_region
plt.imshow(img_rgb)
