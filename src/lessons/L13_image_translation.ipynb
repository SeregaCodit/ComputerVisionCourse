# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from core.entities.constants import Paths as p

# %%
IMAGE_PATH = p.IMAGE_ASSETS / "cat1.png"
image = cv2.imread(IMAGE_PATH)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(image_rgb)

# %%
T = np.array([
    [1, 0, 200],
    [0, 1, 200],], dtype=np.float32)
T
# Out:
# array([[  1.,   0., 200.],
#        [  0.,   1., 200.]], dtype=float32)

# %%
height, width, _ = image.shape

img_translated = cv2.warpAffine(image_rgb, T, (width, height))
plt.figure()
plt.imshow(img_translated)
